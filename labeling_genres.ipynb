# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
# %matplotlib inline

# %%
df_genres = pd.read_csv("genres.csv",header=None,names=['class','name'])
df_train  = pd.read_csv("train.csv",header=None,names=["file",'class'])
df_test   = pd.read_csv("test.csv",header=None,names=["file"])

# %%
f,ax = plt.subplots(figsize=(6,5))
classes = df_train['class'].unique()
df_train['class'].hist(ax=ax,bins=len(classes))
ax.set_xticks(sorted(classes),minor =True)
ax.set_xlabel("class")
ax.set_ylabel("Frequency Number")
# Out:
# Text(0,0.5,'Frequency Number')

# %%
# We'll need numpy for some mathematical operations
from __future__ import print_function
import numpy as np

# matplotlib for displaying the output
import matplotlib.pyplot as plt
import matplotlib.style as ms
ms.use('seaborn-muted')
# %matplotlib inline

# and IPython.display for audio output
import IPython.display

# Librosa for audio
import librosa
# And the display module for visualization
import librosa.display

# %%
df_genres
# Out:
#    class                     name
# 0      1                Cải Lương
# 1      2           Nhạc Cách Mạng
# 2      3  Nhạc Dân Ca - Quê Hương
# 3      4               Nhạc Dance
# 4      5           Nhạc Không Lời
# 5      6           Nhạc Thiếu Nhi
# 6      7               Nhạc Trịnh
# 7      8            Nhạc Trữ Tình
# 8      9                 Rap Việt
# 9     10                Rock Việt

# %%
import IPython.display as ipd
ipd.Audio('test/4633884193933950677.mp3')# load a local WAV file
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
df = pd.read_csv("submit.csv",names=["Id","G","T"]).dropna()[["Id",'T']].set_index('Id').astype(int)

# %%
pd.read_csv("docker/submission.csv", index_col=0).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f38b128c990>]],
#       dtype=object)

# %%
pd.read_csv("xgb_submission.csv", index_col=0).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f38b121dd90>]],
#       dtype=object)

# %%
pd.read_csv("val.csv", index_col=0).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f38b11998d0>]],
#       dtype=object)

# %%
pd.read_csv("chaval.csv", index_col=0).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f38b1351c10>]],
#       dtype=object)

# %%
pd.read_csv("train.csv", index_col=0).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f38b09f76d0>]],
#       dtype=object)
